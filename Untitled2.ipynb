# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading dataset "weatherAUS.csv" into "a"

# %%
a= pd.read_csv('weatherAUS.csv')
a.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
a.shape
# Out:
# (145460, 23)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# MISSING DATA ANALYSIS

# %%
missing = round((a.isnull().sum())/(a.isnull().count())*100,1)
missing.sort_values(ascending=False).head()
# Out:
# Sunshine       48.0
# Evaporation    43.2
# Cloud3pm       40.8
# Cloud9am       38.4
# Pressure9am    10.4
# dtype: float64

# %%
sns.heatmap(data=a.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(data=a.isnull(), yticklabels=False, 
            cbar=False, cmap='viridis' )
# Out:
# <Axes: >

# %% [markdown]
# Here, yellow represent the data whichis missing!

# %% [markdown]
# Now, DATA CLEANING:

# %% [markdown]
# Here is the missing data, we can drop these columns!

# %%
a.drop(['Sunshine','Evaporation','Cloud9am','Cloud3pm','Date','Location'],axis=1,inplace=True)

# %%
a.dropna(inplace=True)
sns.heatmap(a.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Now, We don't have any missing data in our dataset now!

# %%
a.head(5)
# Out:
#    MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6           W           44.0          W
# 1      7.4     25.1       0.0         WNW           44.0        NNW
# 2     12.9     25.7       0.0         WSW           46.0          W
# 3      9.2     28.0       0.0          NE           24.0         SE
# 4     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       1007.7       1007.1     16.9     21.8        No           No
# ...

# %% [markdown]
# To apply Machine Learning algorithm, we need to convert categorical variable into some indicator variables

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
a['WindGustDir']= le.fit_transform(a['WindGustDir'])
a['WindDir9am']= le.fit_transform(a['WindDir9am'])
a['WindDir3pm']= le.fit_transform(a['WindDir3pm'])
a['RainToday']= le.fit_transform(a['RainToday'])
a['RainTomorrow']= le.fit_transform(a['RainTomorrow'])

# %%
a.head(3)
# Out:
#       MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 6049     17.9     35.2       0.0           11           48.0           1
# 6050     18.4     28.9       0.0            8           37.0          10
# 6052     19.4     37.6       0.0            5           46.0           5
#
#       WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 6049          12           6.0          20.0         20.0         13.0
# 6050          10          19.0          19.0         30.0          8.0
# 6052           6          30.0          15.0         42.0         22.0
#
#       Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 6049       1006.3       1004.4     26.6     33.4          0             0
# 6050       1012.9       1012.1     20.3     27.0          0             0
# 6052       1012.3       1009.2     28.7     34.9          0             0

# %% [markdown]
# Model Building - Logistic Regression

# %%
x= a.drop(['RainTomorrow'],axis=1)
y=a['RainTomorrow']

# %%
plt.figure(figsize = (6,6))
sns.scatterplot(x='MaxTemp',y='MinTemp',hue= 'RainTomorrow', palette ='inferno', data=a)
# Out:
# <Axes: xlabel='MaxTemp', ylabel='MinTemp'>

# %%
plt.figure(figsize = (6,6))
sns.scatterplot(x='Humidity9am',y='Temp9am',hue= 'RainTomorrow', palette ='inferno', data=a)
# Out:
# <Axes: xlabel='Humidity9am', ylabel='Temp9am'>

# %% [markdown]
# HEATMAP -- CORRELATION

# %%
plt.figure(figsize = (6,6))
sns.heatmap(a.corr())
# Out:
# <Axes: >

# %% [markdown]
# TRAINING

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
logR = LogisticRegression()

# %%
logR.fit(x_train, y_train)
# Out:
# C:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# PREDICTIONS

# %%
predictions = logR.predict(x_test)

# %%
predictions
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# MESURUING MODEL PERFORMANCE

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[8315  443]
#  [1326 1200]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      8758
#            1       0.73      0.48      0.58      2526
#
#     accuracy                           0.84     11284
#    macro avg       0.80      0.71      0.74     11284
# weighted avg       0.83      0.84      0.83     11284

# %%
score = logR.score(x_test, y_test)
print(score)
# Out:
# 0.8432293512938674

# %% [markdown]
# The logistic Regression model accuracy score is 0.84
